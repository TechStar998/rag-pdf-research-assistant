# %%
# !pip uninstall -y langchain langchain-core langchain-community langchain-openai openai

# !pip install langchain==0.1.16 \
             langchain-community==0.0.32 \
             langchain-core==0.1.42 \
             openai==0.28 \
             faiss-cpu \
             tiktoken \
             pypdf
# Out:
# Found existing installation: langchain 0.1.16
# Uninstalling langchain-0.1.16:
#   Successfully uninstalled langchain-0.1.16
# Found existing installation: langchain-core 0.1.42
# Uninstalling langchain-core-0.1.42:
#   Successfully uninstalled langchain-core-0.1.42
# Found existing installation: langchain-community 0.0.32
# Uninstalling langchain-community-0.0.32:
#   Successfully uninstalled langchain-community-0.0.32
# WARNING: Skipping langchain-openai as it is not installed.
# Found existing installation: openai 0.28.0
# Uninstalling openai-0.28.0:
#   Successfully uninstalled openai-0.28.0
# ...
#   Using cached langchain-0.1.16-py3-none-any.whl.metadata (13 kB)
# ...
#   Using cached langchain_community-0.0.32-py3-none-any.whl.metadata (8.5 kB)
# ...
#   Using cached langchain_core-0.1.42-py3-none-any.whl.metadata (5.9 kB)
# ...
#   Using cached openai-0.28.0-py3-none-any.whl.metadata (13 kB)
# ...
# Using cached langchain-0.1.16-py3-none-any.whl (817 kB)
# ...

# %%
# !pip uninstall -y transformers peft accelerate sentence-transformers
# Out:
# Found existing installation: transformers 4.41.2
# Uninstalling transformers-4.41.2:
#   Successfully uninstalled transformers-4.41.2
# WARNING: Skipping peft as it is not installed.
# Found existing installation: accelerate 0.30.1
# Uninstalling accelerate-0.30.1:
#   Successfully uninstalled accelerate-0.30.1
# Found existing installation: sentence-transformers 2.7.0
# Uninstalling sentence-transformers-2.7.0:
#   Successfully uninstalled sentence-transformers-2.7.0

# %%
# !pip install transformers==4.41.2
# !pip install accelerate==0.30.1
# Out:
# ...
#   Using cached transformers-4.41.2-py3-none-any.whl.metadata (43 kB)
# ...
# Using cached transformers-4.41.2-py3-none-any.whl (9.1 MB)
# ...
#   Using cached accelerate-0.30.1-py3-none-any.whl.metadata (18 kB)
# ...
# Using cached accelerate-0.30.1-py3-none-any.whl (302 kB)
# ...

# %%
import os #restarting run time

# %%
from langchain.text_splitter import RecursiveCharacterTextSplitter
from langchain.chains import RetrievalQA, ConversationalRetrievalChain
from langchain.document_loaders import PyPDFLoader
from langchain.embeddings.openai import OpenAIEmbeddings
from langchain.chat_models import ChatOpenAI

# %%
from langchain_community.document_loaders import PyPDFLoader

# %%
from google.colab import files

# %%
uploaded = files.upload()
# Out:
#      <input type="file" id="files-26dd1c05-4a58-4956-8d2c-47b2ab77e2c1" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-26dd1c05-4a58-4956-8d2c-47b2ab77e2c1">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
file_path = "Project Main File (compressed).pdf"

loader = PyPDFLoader(file_path)
data = loader.load()

# %%
from langchain.text_splitter import RecursiveCharacterTextSplitter
print(f"You have {len(data)} documents in your data ")
print(f"There are {len(data[0].page_content)} characters in your document")
text_splitter = RecursiveCharacterTextSplitter(chunk_size = 2000, chunk_overlap = 0)
texts = text_splitter.split_documents(data)

print(f"You have {len(texts)} pages")
# Out:
# You have 10 documents in your data
# There are 704 characters in your document
# You have 13 pages

# %%
# !pip install sentence-transformers
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 588.9/588.9 kB 9.6 MB/s eta 0:00:00
# ...

# %%
from langchain_community.embeddings import HuggingFaceEmbeddings

embedding = HuggingFaceEmbeddings()
# Out:
# /usr/local/lib/python3.12/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/huggingface_hub/file_download.py:949: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(

# %%
from langchain_community.vectorstores import FAISS

docsearch = FAISS.from_documents(texts, embedding)

# %%
print(len(texts))              # number of chunks
print(texts[0].page_content)  # first chunk text
# Out:
# 13
# IMAGINETIX(Image To Image
# Translation Using GAN)
# Project Submitted in Partial Fulfilment of the Requirements for
# Award of the Degree of
# Bachelor of Technology (CSE)
# Student Name Reg. Number Email ID
# Samriddhi Banerjee 220100416224 samriddhibanerjee04@gmail.com
# Mahika Roy 220100301284 mahikaroy2004@gmail.com
# Sanjukta Malakar 220100897933 sanjuktamalakar2207@gmail.com
# Sreyoshi Ghosh 220100966453 ghoshsreyoshi3@gmail.com
# Submission Date:April 08, 2026
# Under the supervision of
# Prof. (Dr.) Rana Majumdar
# Professor
# Department of Computer Science
# Sister Nivedita University, Newtown
# Kolkata, West Bengal
# DEPARTMENT OF COMPUTER SCIENCE
# Sister Nivedita University, Newtown
# Kolkata, West Bengal
# April 08, 2026

# %%
query = "Summarize the main topic of the project."

docs = docsearch.similarity_search(query, k=3)

for i, doc in enumerate(docs):
    print(f"\nResult {i+1}")
    print(doc.page_content[:1000])
# Out:
# Result 1
# Chapter 6. Conclusion and Future Work
# 6.4 Future Scope / Extensions
# ■Model Improvement:Future work can focus on improving output quality by experimenting
# with advanced architectures like diffusion models, and training on larger, more diverse
# datasets to enhance generalization.
# ■Real-Time Processing:Optimizing the model for faster inference could enable real-time
# image enhancement, which would be useful for live satellite feeds or drone-based applications.
# ■Multi-Condition Handling:Currently focused on cloud removal and color correction,
# the system can be extended to handle additional distortions like haze, noise, or low
# resolution.
# ■User Customization:Adding controls for users to adjust enhancement levels or select
# different processing modes could improve usability and flexibility.
# ■Deployment & Scalability:Deploying the model on cloud platforms and integrating
# ...

# %% [markdown]
# **IMPORTING THE PRETRAINED MODELS OF HUGGING FACE**

# %%
# !pip install transformers accelerate

# %%
# !pip install transformers==4.41.2

# %%
from transformers import pipeline
pipe = pipeline(
    "text2text-generation",
    model="google/flan-t5-base" #pretrained language model by google
)

# %%
context = "\n".join([doc.page_content for doc in docs])

# %%
prompt = f"""
You are a helpful AI assistant.

Use the context below to answer the question clearly and in detail."

Context:
{context}

Question:
{query}
"""

# %%
result = pipe(
    prompt,
    max_new_tokens=256,
    do_sample=True,
    temperature=0.3
)

print(result[0]['generated_text'])
# Out:
# To identify and recommend the most effective algorithms for transforming true-color images to false-color representations and converting cloudy satellite images into de-clouded outputs. To enhance overall image clarity and interpretability for downstream remote sensing tasks. To develop a reliable evaluation approach that compares different models using consistent metrics and datasets. To create a framework that supports objective comparison and evaluation of different image transformation techniques.
